# %%
# To ignore warnings
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

from sklearn import metrics

# %matplotlib inline

# %% [markdown]
# ## Load the data
# The read_csv() function can now be used to load the dataset into pandas and mount it to a disk. This allows Colab to access the drive and transforms the CSV file into a Pandas dataframe.

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/final_data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## View the dataframe
# The shape, head, tail, and columns methods of the panadas functions allow us to quickly gauge the size of our dataset. These techniques help us gain a deeper understanding of the data.

# %% [markdown]
# df.head(2)

# %%
df.shape
# Out:
# (10754, 22)

# %%
df.head(2)
# Out:
#                                 player               team          name  \
# 0   /david-de-gea/profil/spieler/59377  Manchester United  David de Gea
# 1  /jack-butland/profil/spieler/128899  Manchester United  Jack Butland
#
#      position  height   age  appearance  goals  assists  yellow cards  ...  \
# 0  Goalkeeper   189.0  32.0         104    0.0      0.0      0.009585  ...
# 1  Goalkeeper   196.0  30.0          15    0.0      0.0      0.069018  ...
#
#    goals conceded  clean sheets  minutes played  days_injured  games_injured  \
# 0        1.217252      0.335463            9390            42              5
# 1        1.242331      0.207055            1304           510             58
#
#    award  current_value  highest_value  position_encoded  winger
# 0     13       15000000       70000000                 1       0
# 1      1        1500000       22000000                 1       0
#
# [2 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['player', 'team', 'name', 'position', 'height', 'age', 'appearance',
#        'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards',
#        'goals conceded', 'clean sheets', 'minutes played', 'days_injured',
#        'games_injured', 'award', 'current_value', 'highest_value',
#        'position_encoded', 'winger'],
#       dtype='object')

# %% [markdown]
# ## Profiling Data
# The practice of thoroughly analyzing the data in an existing dataset and gathering statistics and information about it is known as data profiling.

# %% [markdown]
# # Preprocess The Data

# %%
df.describe()
# Out:
#              height           age    appearance         goals       assists  \
# count  10754.000000  10754.000000  10754.000000  10754.000000  10754.000000
# mean     181.240353     26.041903     36.407011      0.125554      0.086978
# std        6.969818      4.777629     26.526541      0.235585      0.143351
# min      156.000000     15.000000      0.000000      0.000000      0.000000
# 25%      176.000000     22.000000     12.000000      0.000000      0.000000
# 50%      181.240353     26.000000     35.000000      0.045969      0.040773
# 75%      186.000000     29.000000     59.000000      0.172263      0.133136
# max      206.000000     43.000000    107.000000     11.250000      4.000000
#
#        yellow cards  second yellow cards     red cards  goals conceded  \
# count  10754.000000         10754.000000  10754.000000    10754.000000
# mean       0.189757             0.004666      0.006826        0.131655
# std        0.432388             0.025232      0.081143        0.442335
# min        0.000000             0.000000      0.000000        0.000000
# 25%        0.053191             0.000000      0.000000        0.000000
# 50%        0.150250             0.000000      0.000000        0.000000
# 75%        0.248276             0.000000      0.000000        0.000000
# max       30.000000             1.000000      6.923077        9.000000
#
#        clean sheets  minutes played  days_injured  games_injured  \
# count  10754.000000    10754.000000  10754.000000   10754.000000
# mean       0.044881     2470.789381    117.961689      15.826297
# std        0.924437     2021.703271    175.206827      23.383606
# min        0.000000        0.000000      0.000000       0.000000
# 25%        0.000000      660.000000      0.000000       0.000000
# 50%        0.000000     2101.500000     37.000000       5.000000
# 75%        0.000000     3968.000000    181.000000      24.000000
# max       90.000000     9510.000000   2349.000000     339.000000
#
#               award  current_value  highest_value  position_encoded  \
# count  10754.000000   1.075400e+04   1.075400e+04      10754.000000
# mean       1.960759   3.622971e+06   6.152606e+06          2.713223
# std        3.743936   9.095410e+06   1.338988e+07          0.986356
# min        0.000000   0.000000e+00   0.000000e+00          1.000000
# 25%        0.000000   3.000000e+05   4.500000e+05          2.000000
# 50%        1.000000   8.000000e+05   1.500000e+06          3.000000
# 75%        2.000000   3.000000e+06   5.000000e+06          4.000000
# max       92.000000   1.800000e+08   2.000000e+08          4.000000
#
#              winger
# count  10754.000000
# mean       0.307513
# std        0.461485
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10754 entries, 0 to 10753
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player               10754 non-null  object
#  1   team                 10754 non-null  object
#  2   name                 10754 non-null  object
#  3   position             10754 non-null  object
#  4   height               10754 non-null  float64
#  5   age                  10754 non-null  float64
#  6   appearance           10754 non-null  int64
#  7   goals                10754 non-null  float64
#  8   assists              10754 non-null  float64
#  9   yellow cards         10754 non-null  float64
#  10  second yellow cards  10754 non-null  float64
#  11  red cards            10754 non-null  float64
#  12  goals conceded       10754 non-null  float64
#  13  clean sheets         10754 non-null  float64
#  14  minutes played       10754 non-null  int64
#  15  days_injured         10754 non-null  int64
#  16  games_injured        10754 non-null  int64
#  17  award                10754 non-null  int64
#  18  current_value        10754 non-null  int64
#  19  highest_value        10754 non-null  int64
#  20  position_encoded     10754 non-null  int64
#  21  winger               10754 non-null  int64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 1.8+ MB

# %%
df["team"].value_counts(ascending=False)
# Out:
# team
# Daejeon Hana Citizen      46
# Jeonbuk Hyundai Motors    46
# FC Seoul                  45
# Gangwon FC                43
# Daegu FC                  42
#                           ..
# FC Barcelona              22
# Atlético de Madrid        22
# CA Osasuna                22
# Hatayspor                 12
# Gaziantep FK               6
# Name: count, Length: 374, dtype: int64

# %%
df["award"].value_counts(ascending=False)
# Out:
# award
# 0     4773
# 1     2211
# 2     1223
# 3      730
# 4      460
# 5      323
# 6      216
# 7      199
# 8      121
# 9      110
# 10      72
# 11      61
# 13      42
# 12      35
# 14      35
# 15      21
# 17      16
# 18      16
# 16      13
# 19      11
# 20      11
# 33       6
# 22       6
# 21       4
# 25       4
# 24       4
# 26       4
# 23       3
# 35       2
# 36       2
# 29       2
# 27       2
# 32       2
# 37       2
# 31       1
# 42       1
# 28       1
# 92       1
# 34       1
# 30       1
# 57       1
# 65       1
# 53       1
# 38       1
# 43       1
# 90       1
# Name: count, dtype: int64

# %%
df["winger"].unique()
# Out:
# array([0, 1])

# %%
df["position_encoded"].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df["height"].unique()
# Out:
# array([189.       , 196.       , 188.       , 175.       , 191.       ,
#        194.       , 187.       , 185.       , 186.       , 178.       ,
#        169.       , 180.       , 183.       , 182.       , 177.       ,
#        184.       , 181.       , 179.       , 172.       , 174.       ,
#        197.       , 195.       , 190.       , 176.       , 170.       ,
#        192.       , 167.       , 198.       , 199.       , 193.       ,
#        165.       , 200.       , 173.       , 163.       , 171.       ,
#        168.       , 166.       , 202.       , 181.2403529, 164.       ,
#        206.       , 160.       , 204.       , 156.       , 162.       ,
#        159.       , 161.       ])

# %%
df.shape
# Out:
# (10754, 22)

# %% [markdown]
# ## Data Quality Checks
#  involve the process of ensuring that the data is accurate, complete, consistent, relevant, and reliable

# %% [markdown]
# Here are typical steps involved in checking data quality

# %% [markdown]
#  **1.Reliability** :
#
# Evaluate the data's source and collection process to determine its trustworthiness

# %%
# Licensed in kaggle

# %% [markdown]
# **2.Timeliness**:
#  Ensure the data is up-to-date and reflective of the current situation or the period of interest for the analysis

# %%
#in 2 season 2021-2022 and 2022-2023

# %% [markdown]
# **3.Consistency**:
#
# *Confirm* that the data is consistent within the dataset and across multiple data sources.For example, the same data point should not have different values in different places

# %%
#Consistent

# %% [markdown]
# **4.Relevance:**
#
# Assess whether the data is appropriate and applicable for the intended analysis. Data that is not relevant can skew results and lead to incorrect conclusions.

# %% [markdown]
# **The following are important factors for relevance:**
#
# 1. Sample Appropriateness: Verify that the goals of your analysis are met by the data sample you have chosen. For example, using statistics from the Northern region will not provide reliable information for the Kingdom's Western region.
#
#
# 2. Variable Selection: We can use the drop() technique to remove any columns that are irrelevant to our study. Since we are working with columns, we will set the "axis" parameter to 1. To make the change permanent, we will set the "inplace" argument to True.

# %%
# the data is relevant

# %% [markdown]
# **5. Uniqueness:**
#
# Check for and remove duplicate records to prevent skewed analysis results.

# %%
df.duplicated().sum()
# no duplicates columns
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64

# %%
# check columns types
df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['player', 'team', 'name', 'position', 'height', 'age', 'appearance',
#        'goals', 'assists', 'yellow cards', 'second yellow cards', 'red cards',
#        'goals conceded', 'clean sheets', 'minutes played', 'days_injured',
#        'games_injured', 'award', 'current_value', 'highest_value',
#        'position_encoded', 'winger'],
#       dtype='object')

# %%
df.shape
# Out:
# (10754, 22)

# %%
# uniqeness
df.drop_duplicates(inplace=True)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [player, team, name, position, height, age, appearance, goals, assists, yellow cards, second yellow cards, red cards, goals conceded, clean sheets, minutes played, days_injured, games_injured, award, current_value, highest_value, position_encoded, winger]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Completeness
df.isnull().sum()
# Out:
# player                 0
# team                   0
# name                   0
# position               0
# height                 0
# age                    0
# appearance             0
# goals                  0
# assists                0
# yellow cards           0
# second yellow cards    0
# red cards              0
# goals conceded         0
# clean sheets           0
# minutes played         0
# days_injured           0
# games_injured          0
# award                  0
# current_value          0
# highest_value          0
# position_encoded       0
# winger                 0
# dtype: int64

# %%
# Accurecy types
df.dtypes
# Out:
# player                  object
# team                    object
# name                    object
# position                object
# height                 float64
# age                    float64
# appearance               int64
# goals                  float64
# assists                float64
# yellow cards           float64
# second yellow cards    float64
# red cards              float64
# goals conceded         float64
# clean sheets           float64
# minutes played           int64
# days_injured             int64
# games_injured            int64
# award                    int64
# current_value            int64
# highest_value            int64
# position_encoded         int64
# winger                   int64
# dtype: object

# %%
df.drop(columns=["team",'yellow cards', 'second yellow cards', 'red cards',"name", "player",'goals conceded','clean sheets'], inplace=True)

# %%
#drop whatever doesn't consider normal as a football player desription

df.drop(df[(df['age'] <= 18) | (df['age'] >= 38)].index, inplace=True)
df.drop(df[(df['current_value'] == 0) | (df['highest_value'] == 0)].index, inplace=True)
df.drop(df[(df['appearance'] == 0.00)].index, inplace=True)
df.drop(df[(df['height'] <= 140) | (df['height'] > 200)].index, inplace=True)
df.drop(df[df['current_value'] >= 50000000].index, inplace=True)
df.drop(df[df['current_value'] < 10000].index, inplace=True)
df.drop(df[df['highest_value'] >= 50000000].index, inplace=True)
df.drop(df[df['highest_value'] < 10000].index, inplace=True)
df.drop(df[(df['goals'] == 0.00)].index, inplace=True)

# %%
df.shape
# Out:
# (5546, 14)

# %% [markdown]
# **B. Feature engineering**
#
#
# 1.Feature scaling
# 2.Aggregation
# 3.One hot coding

# %%
df.head(2)
# Out:
#               position  height   age  appearance     goals   assists  \
# 9   Defender Left-Back   178.0  27.0          74  0.015374  0.169115
# 10  Defender Left-Back   169.0  23.0          89  0.012619  0.063096
#
#     minutes played  days_injured  games_injured  award  current_value  \
# 9             5854           443             70      4       35000000
# 10            7132           182             15      3       22000000
#
#     highest_value  position_encoded  winger
# 9        42000000                 2       1
# 10       22000000                 2       1

# %%
categorical_features = ['position']
numeric_features = ['height', 'age', 'appearance', 'goals', 'assists',
       'yellow cards', 'second yellow cards', 'red cards', 'goals conceded',
       'clean sheets', 'minutes played', 'days_injured', 'games_injured',
       'award', 'current_value', 'highest_value', 'winger']

# %%
for i in categorical_features:
    print (df[i].value_counts())
# Out:
# position
# Attack Centre-Forward         965
# Defender Centre-Back          944
# midfield-CentralMidfield      698
# Attack-RightWinger            519
# Attack-LeftWinger             493
# midfield-AttackingMidfield    487
# midfield-DefensiveMidfield    434
# Defender Right-Back           416
# Defender Left-Back            390
# Other                         200
# Name: count, dtype: int64

# %%
# one hot coding
df = pd.get_dummies(df, columns=categorical_features)

# %%
df.shape
# Out:
# (5546, 23)

# %%
df.head(2)
# Out:
#     height   age  appearance     goals   assists  minutes played  \
# 9    178.0  27.0          74  0.015374  0.169115            5854
# 10   169.0  23.0          89  0.012619  0.063096            7132
#
#     days_injured  games_injured  award  current_value  ...  \
# 9            443             70      4       35000000  ...
# 10           182             15      3       22000000  ...
#
#     position_Attack Centre-Forward  position_Attack-LeftWinger  \
# 9                            False                       False
# 10                           False                       False
#
#     position_Attack-RightWinger  position_Defender Centre-Back  \
# 9                         False                          False
# 10                        False                          False
#
#     position_Defender Left-Back  position_Defender Right-Back  position_Other  \
# 9                          True                         False           False
# 10                         True                         False           False
#
#     position_midfield-AttackingMidfield  position_midfield-CentralMidfield  \
# 9                                 False                              False
# 10                                False                              False
#
#     position_midfield-DefensiveMidfield
# 9                                 False
# 10                                False
#
# [2 rows x 23 columns]

# %%
# Calculate the 25th and 85th percentiles of 'current_value'
p25 = df['current_value'].quantile(0.25)
p65 = df['current_value'].quantile(0.65)

# Function to categorize 'current_value' based on percentiles
def categorize_current_value(current_value):
    if current_value < p25:
        return 'Cheap'
    elif current_value < p65:
        return 'Moderate'
    else:
        return 'Expensive'

# Apply the function to create a new column 'current_value_category'
df['current_value_category'] = df['current_value'].apply(categorize_current_value)

# Optionally, drop the original 'current_value' column
df.drop('current_value', axis=1, inplace=True)

# Verify the distribution of the new categories
print(df['current_value_category'].value_counts())
# Out:
# current_value_category
# Moderate     2202
# Expensive    1998
# Cheap        1346
# Name: count, dtype: int64

# %%
p25, p65
# Out:
# (500000.0, 2500000.0)

# %%
encoder = LabelEncoder()
df['current_value_category'] = encoder.fit_transform(df['current_value_category'])

# %%
df.columns
# Out:
# Index(['height', 'age', 'appearance', 'goals', 'assists', 'minutes played',
#        'days_injured', 'games_injured', 'award', 'highest_value',
#        'position_encoded', 'winger', 'position_Attack Centre-Forward',
#        'position_Attack-LeftWinger', 'position_Attack-RightWinger',
#        'position_Defender Centre-Back', 'position_Defender Left-Back',
#        'position_Defender Right-Back', 'position_Other',
#        'position_midfield-AttackingMidfield',
#        'position_midfield-CentralMidfield',
#        'position_midfield-DefensiveMidfield', 'current_value_category'],
#       dtype='object')

# %% [markdown]
#  **C. Feature selection**

# %%
correlation = df.corr(numeric_only=True)
print(correlation['current_value_category'].sort_values(ascending=False))
# Out:
# current_value_category                 1.000000
# appearance                             0.139336
# minutes played                         0.132774
# age                                    0.089319
# award                                  0.081002
# games_injured                          0.079154
# days_injured                           0.070009
# assists                                0.065031
# position_midfield-AttackingMidfield    0.023407
# position_Attack-RightWinger            0.012539
# position_midfield-DefensiveMidfield    0.008567
# winger                                 0.005092
# position_Attack-LeftWinger             0.004769
# position_encoded                       0.002883
# position_Defender Centre-Back          0.000182
# position_Defender Left-Back           -0.001074
# position_Defender Right-Back          -0.003670
# position_Attack Centre-Forward        -0.006026
# position_midfield-CentralMidfield     -0.006049
# height                                -0.007349
# highest_value                         -0.008476
# goals                                 -0.043988
# position_Other                        -0.045433
# Name: current_value_category, dtype: float64

# %%
# Set the correlation threshold
threshold = 0.09 # You can change this value based on your requirement

# Filter the correlations
# We use `abs()` for absolute value to consider both strong positive and negative correlations
selected_features = correlation[abs(correlation['current_value_category']) > \
threshold]['current_value_category'].index
selected_features
# Out:
# Index(['appearance', 'minutes played', 'current_value_category'], dtype='object')

# %%
selected_features =['appearance', 'minutes played', 'current_value_category']

# %%
df.columns
# Out:
# Index(['height', 'age', 'appearance', 'goals', 'assists', 'minutes played',
#        'days_injured', 'games_injured', 'award', 'highest_value',
#        'position_encoded', 'winger', 'position_Attack Centre-Forward',
#        'position_Attack-LeftWinger', 'position_Attack-RightWinger',
#        'position_Defender Centre-Back', 'position_Defender Left-Back',
#        'position_Defender Right-Back', 'position_Other',
#        'position_midfield-AttackingMidfield',
#        'position_midfield-CentralMidfield',
#        'position_midfield-DefensiveMidfield', 'current_value_category'],
#       dtype='object')

# %%
df.head()
# Out:
#     height   age  appearance     goals   assists  minutes played  \
# 9    178.0  27.0          74  0.015374  0.169115            5854
# 10   169.0  23.0          89  0.012619  0.063096            7132
# 12   183.0  24.0          72  0.032293  0.048439            5574
# 15   191.0  26.0          76  0.096010  0.038404            4687
# 20   181.0  20.0          39  0.129125  0.064562            2788
#
#     days_injured  games_injured  award  highest_value  ...  \
# 9            443             70      4       42000000  ...
# 10           182             15      3       22000000  ...
# 12           328             49      3       35000000  ...
# 15           249             53      2       35000000  ...
# 20             0              0      1         800000  ...
#
#     position_Attack-LeftWinger  position_Attack-RightWinger  \
# 9                        False                        False
# 10                       False                        False
# 12                       False                        False
# 15                       False                        False
# 20                       False                        False
#
#     position_Defender Centre-Back  position_Defender Left-Back  \
# 9                           False                         True
# 10                          False                         True
# 12                          False                        False
# 15                          False                        False
# 20                          False                        False
#
#     position_Defender Right-Back  position_Other  \
# 9                          False           False
# 10                         False           False
# 12                          True           False
# 15                         False           False
# 20                         False           False
#
#     position_midfield-AttackingMidfield  position_midfield-CentralMidfield  \
# 9                                 False                              False
# 10                                False                              False
# 12                                False                              False
# 15                                False                              False
# 20                                False                               True
#
#     position_midfield-DefensiveMidfield  current_value_category
# 9                                 False                       1
# 10                                False                       1
# 12                                False                       1
# 15                                 True                       1
# 20                                False                       2
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Data should be prepared.

# %%
# Prepare data
X = df


# sacle the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (5546, 23)

# %% [markdown]
# ## Buliding the Model

# %%
wcss = []
for i in range(1, 30):  # Test 1 to 10 clusters
    kmeans = KMeans(n_clusters=i,
                    init='k-means++',
                    max_iter=300,
                    n_init=10,
                    random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)  # inertia_ is the WCSS

# %%
# 3. Plot the Elbow Curve
plt.figure(figsize=(10, 6))
plt.plot(range(1, 30), wcss,  marker='o', linestyle='-', color='b')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
# Optional: Apply k-Means using the optimal number of clusters
optimal_clusters = 8 # This might change based on your actual elbow curve analysis
model = KMeans(n_clusters=optimal_clusters, init='k-means++', max_iter=300, n_init=10, random_state=0)

# %% [markdown]
# ## Train and Test the Model

# %%
# Fit the model on the training data
y_pred = model.fit_predict(X_scaled)

# %% [markdown]
# ## Evaluating the Model

# %%
X.head(2)
# Out:
#     height   age  appearance     goals   assists  minutes played  \
# 9    178.0  27.0          74  0.015374  0.169115            5854
# 10   169.0  23.0          89  0.012619  0.063096            7132
#
#     days_injured  games_injured  award  highest_value  ...  \
# 9            443             70      4       42000000  ...
# 10           182             15      3       22000000  ...
#
#     position_Attack-LeftWinger  position_Attack-RightWinger  \
# 9                        False                        False
# 10                       False                        False
#
#     position_Defender Centre-Back  position_Defender Left-Back  \
# 9                           False                         True
# 10                          False                         True
#
#     position_Defender Right-Back  position_Other  \
# 9                          False           False
# 10                         False           False
#
#     position_midfield-AttackingMidfield  position_midfield-CentralMidfield  \
# 9                                 False                              False
# 10                                False                              False
#
#     position_midfield-DefensiveMidfield  current_value_category
# 9                                 False                       1
# 10                                False                       1
#
# [2 rows x 23 columns]

# %%
# Plotting the clusters with optimal number
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=y_pred, s=50, cmap='viridis')

centers = model.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.title(f'K-Means Clustering with {optimal_clusters} Clusters')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
X['kmeans'] = y_pred

# %%
X['kmeans'].value_counts()
# Out:
# kmeans
# 1    965
# 2    956
# 5    806
# 3    707
# 0    698
# 7    493
# 6    487
# 4    434
# Name: count, dtype: int64

# %%
X[X['kmeans']==0]
# Out:
#        height   age  appearance     goals   assists  minutes played  \
# 20      181.0  20.0          39  0.129125  0.064562            2788
# 44      178.0  24.0          74  0.019876  0.039753            4528
# 73      178.0  24.0          78  0.079491  0.079491            5661
# 95      177.0  25.0          75  0.134820  0.134820            6008
# 96      180.0  22.0          73  0.203352  0.152514            5311
# ...       ...   ...         ...       ...       ...             ...
# 10638   179.0  28.0          53  0.086042  0.064532            4184
# 10639   182.0  24.0          40  0.047145  0.094290            1909
# 10687   173.0  30.0          63  0.133655  0.183776            5387
# 10740   175.0  33.0          44  0.225941  0.075314            3585
# 10741   179.0  34.0          33  0.265263  0.000000            2375
#
#        days_injured  games_injured  award  highest_value  ...  \
# 20                0              0      1         800000  ...
# 44                0              0      1        8000000  ...
# 73                4              1      1       25000000  ...
# 95               64              7      1       38000000  ...
# 96               46              4      0       32000000  ...
# ...             ...            ...    ...            ...  ...
# 10638             0              0      0         500000  ...
# 10639             0              0      0         250000  ...
# 10687             0              0      3         600000  ...
# 10740            41              5      1        2000000  ...
# 10741            93             10      1         750000  ...
#
#        position_Attack-RightWinger  position_Defender Centre-Back  \
# 20                           False                          False
# 44                           False                          False
# 73                           False                          False
# 95                           False                          False
# 96                           False                          False
# ...                            ...                            ...
# 10638                        False                          False
# 10639                        False                          False
# 10687                        False                          False
# 10740                        False                          False
# 10741                        False                          False
#
#        position_Defender Left-Back  position_Defender Right-Back  \
# 20                           False                         False
# 44                           False                         False
# 73                           False                         False
# 95                           False                         False
# 96                           False                         False
# ...                            ...                           ...
# 10638                        False                         False
# 10639                        False                         False
# 10687                        False                         False
# 10740                        False                         False
# 10741                        False                         False
#
#        position_Other  position_midfield-AttackingMidfield  \
# 20              False                                False
# 44              False                                False
# 73              False                                False
# 95              False                                False
# 96              False                                False
# ...               ...                                  ...
# 10638           False                                False
# 10639           False                                False
# 10687           False                                False
# 10740           False                                False
# 10741           False                                False
#
#        position_midfield-CentralMidfield  position_midfield-DefensiveMidfield  \
# 20                                  True                                False
# 44                                  True                                False
# 73                                  True                                False
# 95                                  True                                False
# 96                                  True                                False
# ...                                  ...                                  ...
# 10638                               True                                False
# 10639                               True                                False
# 10687                               True                                False
# 10740                               True                                False
# 10741                               True                                False
#
#        current_value_category  kmeans
# 20                          2       0
# 44                          1       0
# 73                          1       0
# 95                          1       0
# 96                          1       0
# ...                       ...     ...
# 10638                       0       0
# 10639                       0       0
# 10687                       2       0
# 10740                       2       0
# 10741                       0       0
#
# [698 rows x 24 columns]

# %%
X.columns
# Out:
# Index(['height', 'age', 'appearance', 'goals', 'assists', 'minutes played',
#        'days_injured', 'games_injured', 'award', 'highest_value',
#        'position_encoded', 'winger', 'position_Attack Centre-Forward',
#        'position_Attack-LeftWinger', 'position_Attack-RightWinger',
#        'position_Defender Centre-Back', 'position_Defender Left-Back',
#        'position_Defender Right-Back', 'position_Other',
#        'position_midfield-AttackingMidfield',
#        'position_midfield-CentralMidfield',
#        'position_midfield-DefensiveMidfield', 'current_value_category',
#        'kmeans'],
#       dtype='object')

# %%
sns.scatterplot(data = X , x = 'minutes played', y = 'age', hue = 'kmeans')
# Out:
# <Axes: xlabel='minutes played', ylabel='age'>

# %%
sns.scatterplot(data = X , x = 'minutes played', y = 'award', hue = 'kmeans')
# Out:
# <Axes: xlabel='minutes played', ylabel='award'>

# %%
import plotly
import plotly.express as px

fig = px.scatter_3d(X, x='minutes played', y='age', z='highest_value',
              color='kmeans')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a7acf054-4176-4bc0-a8c3-62bc4f55a7fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7acf054-4176-4bc0-a8c3-62bc4f55a7fc")) {                    Plotly.newPlot(                        "a7acf054-4176-4bc0-a8c3-62bc4f55a7fc",                        [{"hovertemplate":"minutes played=%{x}\u003cbr\u003eage=%{y}\u003cbr\u003ehighest_value=%{z}\u003cbr\u003ekmeans=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[5,5,5,4,0,7,1,2,2,5,5,5,0,6,6,6,7,7,3,1,1,1,2,2,2,2,5,5,5,5,4,0,7,3,1,2,2,2,5,5,4,4,0,0,0,7,3,3,1,2,2,2,2,5,5,5,4,4,4,0,0,7,7,3,3,1,1,2,2,2,2,5,5,5,5,4,4,0,0,6,7,7,7,7,3,1,1,1,1,2,2,2,2,5,5,5,0,0,0,0,6,6,7,3,1,1,2,2,2,2,2,5,5,4,4,0,0,